# %% [markdown]
# # MÔ TẢ BÀI TOÁN
#
# - Input: Chữ số viết tay
# - Output: Kết quả nhận dạng
#
# Tham khảo: https://machinelearningmastery.com/how-to-develop-a-convolutional-neural-network-from-scratch-for-mnist-handwritten-digit-classification/
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # MNIST Handwritten Digit Classification Dataset
#
# - Các ảnh greyscale có kích thước 28x28

# %%
from tensorflow.keras.datasets import mnist
from matplotlib import pyplot as plt

# load dataset
(trainX, trainy), (testX, testy) = mnist.load_data()

# summarize loaded dataset
print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
print('Test: X=%s, y=%s' % (testX.shape, testy.shape))

# plot first few images
for i in range(9):
  # define subplot
  plt.subplot(330 + 1 + i)
  # plot raw pixel data
  plt.imshow(trainX[i], cmap=plt.get_cmap('gray'))
  # show the figure
  plt.show()
# Out:
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %%
from numpy import mean
from numpy import std
from matplotlib import pyplot as plt
from sklearn.model_selection import KFold
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import SGD
from numpy import argmax
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model

# %% [markdown]
# ## Load Dataset
#
# - we know that the images are all pre-aligned (e.g. each image only contains a hand-drawn digit), that the images all have the same square size of 28×28 pixels, and that the images are grayscale. Therefore, we can load the images and reshape the data arrays to have a single color channel.
# - a one hot encoding for the class element of each sample, transforming the integer into a 10 element binary vector with a 1 for the index of the class value, and 0 values for all other classes

# %%
def load_dataset():
  # load dataset
  (trainX, trainY), (testX, testY) = mnist.load_data()

  # reshape dataset to have a single channel
  trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
  testX = testX.reshape((testX.shape[0], 28, 28, 1))

  # one hot encode target values
  trainY = to_categorical(trainY)
  testY = to_categorical(testY)
  return trainX, trainY, testX, testY

# %% [markdown]
# ## Prepare Pixel Data
#
# - We know that the pixel values for each image in the dataset are unsigned integers in the range between black and white, or 0 and 255.
#
# - We do not know the best way to scale the pixel values for modeling, but we know that some scaling will be required.
#
# - A good starting point is to normalize the pixel values of grayscale images, e.g. rescale them to the range [0,1]. This involves first converting the data type from unsigned integers to floats, then dividing the pixel values by the maximum value.

# %%
def prep_pixels(train, test):
  # convert from integers to floats
  train_norm = train.astype('float32')
  test_norm = test.astype('float32')

  # normalize to range 0-1
  train_norm = train_norm / 255.0
  test_norm = test_norm / 255.0

  # return normalized images
  return train_norm, test_norm

# %% [markdown]
# ## Define Model

# %%
def define_model():
  model = Sequential()
  model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
  model.add(MaxPooling2D((2, 2)))
  model.add(Flatten())
  model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))
  model.add(Dense(10, activation='softmax'))

  # compile model
  opt = SGD(learning_rate=0.01, momentum=0.9)
  model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

  return model

# %% [markdown]
# ## Evaluate Model

# %%
# evaluate a model using k-fold cross-validation
def evaluate_model(dataX, dataY, n_folds=5):
  scores, histories = list(), list()

  # prepare cross validation
  kfold = KFold(n_folds, shuffle=True, random_state=1)

  # enumerate splits
  for train_ix, test_ix in kfold.split(dataX):

    # define model
    model = define_model()

    # select rows for train and test
    trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]

    # fit model
    history = model.fit(trainX, trainY, epochs=10, batch_size=32, validation_data=(testX, testY), verbose=0)

    # evaluate model
    _, acc = model.evaluate(testX, testY, verbose=0)
    print('> %.3f' % (acc * 100.0))

    # stores scores
    scores.append(acc)
    histories.append(history)

  return scores, histories

# %% [markdown]
# ## Present Results

# %%
def summarize_diagnostics(histories):
  for i in range(len(histories)):
    # plot loss
    plt.subplot(2, 1, 1)
    plt.title('Cross Entropy Loss')
    plt.plot(histories[i].history['loss'], color='blue', label='train')
    plt.plot(histories[i].history['val_loss'], color='orange', label='test')

    # plot accuracy
    plt.subplot(2, 1, 2)
    plt.title('Classification Accuracy')
    plt.plot(histories[i].history['accuracy'], color='blue', label='train')
    plt.plot(histories[i].history['val_accuracy'], color='orange', label='test')
    plt.show()

# %%
def summarize_performance(scores):
  # print summary
  print('Accuracy: mean=%.3f std=%.3f, n=%d' % (mean(scores)*100, std(scores)*100, len(scores)))

  # box and whisker plots of results
  plt.boxplot(scores)
  plt.show()

# %%
def run_test_harness():
  # load dataset
  trainX, trainY, testX, testY = load_dataset()

  # prepare pixel data
  trainX, testX = prep_pixels(trainX, testX)

  # evaluate model
  scores, histories = evaluate_model(trainX, trainY)

  # learning curves
  summarize_diagnostics(histories)

  # summarize estimated performance
  summarize_performance(scores)

# %%
# entry point, run the test harness
run_test_harness()
# Out:
# C:\Users\YOGA\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# > 98.425
# > 98.508
# > 98.675
# > 98.700
# > 98.608
# Accuracy: mean=98.583 std=0.103, n=5

# %% [markdown]
# ## Save Final Model

# %%
# run the test harness for evaluating a model
def run_test_harness2():
  # load dataset
  trainX, trainY, testX, testY = load_dataset()

  # prepare pixel data
  trainX, testX = prep_pixels(trainX, testX)
  # define model
  model = define_model()

  # fit model
  model.fit(trainX, trainY, epochs=10, batch_size=32, verbose=0)

  # save model
  model.save('final_model.h5')

# %% [markdown]
# ## Evaluate Final Model

# %%
run_test_harness2()
# Out:
# C:\Users\YOGA\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## Make Prediction

# %% [markdown]
# from tensorflow.keras.preprocessing.image import load_img, img_to_array
#
# def load_image(filename):
#     # Load the image
#     img = load_img(filename, target_size=(28, 28))
#
#     # Convert to array
#     img = img_to_array(img)
#
#     # Normalize pixel values to range [0, 1]
#     img = img / 255.0
#
#     # Reshape to a single sample with a channel dimension
#     img = img.reshape(1, 28, 28, 1)
#
#     return img

# %% [markdown]
# # ĐỌC TẤT CẢ CÁC ẢNH TRONG FILE ĐƯỢC CHỌN Ở DATA

# %%
import os
from PIL import Image

def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        if filename.endswith(".jpg") or filename.endswith(".png"): # Kiểm tra định dạng file
            img = Image.open(os.path.join(folder, filename))
            if img is not None:
                images.append(img)
    return images

folder = "./Data/"
images = load_images_from_folder(folder)

# %%
'''from tensorflow.keras.preprocessing.image import load_img, img_to_array

def load_image(filename):
  # load the image
  img = load_img(filename, color_mode='grayscale', target_size=(28, 28))

  # convert to array
  img = img_to_array(img)

  # reshape into a single sample with 1 channel
  img = img.reshape(1, 28, 28, 1)

  # prepare pixel data
  img = img.astype('float32')
  img = img / 255.0

  return img'''
# Out:
# "from tensorflow.keras.preprocessing.image import load_img, img_to_array\n\ndef load_image(filename):\n  # load the image\n  img = load_img(filename, color_mode='grayscale', target_size=(28, 28))\n\n  # convert to array\n  img = img_to_array(img)\n\n  # reshape into a single sample with 1 channel\n  img = img.reshape(1, 28, 28, 1)\n\n  # prepare pixel data\n  img = img.astype('float32')\n  img = img / 255.0\n\n  return img"

# %%
'''# load an image and predict the class
def run_example():
  # load the image
  img = load_image('./Data/22520148/0/0_0.png')

  # load model
  model = load_model('final_model.h5')

  # predict the class
  predict_value = model.predict(img)

  digit = argmax(predict_value)
  print(digit)'''
# Out:
# "# load an image and predict the class\ndef run_example():\n  # load the image\n  img = load_image('./Data/22520148/0/0_0.png')\n\n  # load model\n  model = load_model('final_model.h5')\n\n  # predict the class\n  predict_value = model.predict(img)\n\n  digit = argmax(predict_value)\n  print(digit)"

# %% [markdown]
# # CHẠY CÁC ẢNH TRONG FILE ĐÃ ĐƯỢC CHỌN Ở TRÊN.
# Trong đoạn code đã bao gồm cả load_image() và run_example()

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import load_model
from numpy import argmax
import os

def load_and_predict_all_images(folder_path, model_path):
    # Load the model
    model = load_model(model_path)

    # Initialize a dictionary to store predictions
    predictions = {}

    # Iterate over all files in the folder
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith('.jpg') or file.lower().endswith('.png'):
                image_path = os.path.join(root, file)
                img = load_image(image_path)
                predict_value = model.predict(img)
                digit = argmax(predict_value)
                predictions[image_path] = digit

    return predictions

# Example usage
folder_path = './Data/'
model_path = 'final_model.h5'
all_predictions = load_and_predict_all_images(folder_path, model_path)

# Print the predictions
for image_path, digit in all_predictions.items():
    print(f"Predicted digit for {image_path}: {digit}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Predicted digit for ./Data/22520083\0\hinh_0_1.jpg: 8
# Predicted digit for ./Data/22520083\0\hinh_0_2.jpg: 8
# Predicted digit for ./Data/22520083\0\hinh_0_3.jpg: 9
# Predicted digit for ./Data/22520083\1\hinh_1_1.jpg: 8
# Predicted digit for ./Data/22520083\1\hinh_1_2.jpg: 8
# Predicted digit for ./Data/22520083\1\hinh_1_3.jpg: 8
# Predicted digit for ./Data/22520083\2\hinh_2_1.jpg: 8
# Predicted digit for ./Data/22520083\2\hinh_2_2.jpg: 8
# Predicted digit for ./Data/22520083\2\hinh_2_3.jpg: 8
# Predicted digit for ./Data/22520083\3\hinh_3_1.jpg: 3
# Predicted digit for ./Data/22520083\3\hinh_3_2.jpg: 8
# Predicted digit for ./Data/22520083\3\hinh_3_3.jpg: 3
# Predicted digit for ./Data/22520083\4\hinh_4_1.jpg: 8
# Predicted digit for ./Data/22520083\4\hinh_4_2.jpg: 8
# Predicted digit for ./Data/22520083\4\hinh_4_3.jpg: 3
# Predicted digit for ./Data/22520083\5\hinh_5_1.jpg: 8
# Predicted digit for ./Data/22520083\5\hinh_5_2.jpg: 3
# Predicted digit for ./Data/22520083\5\hinh_5_3.jpg: 8
# Predicted digit for ./Data/22520083\6\hinh_6_1.jpg: 6
# Predicted digit for ./Data/22520083\6\hinh_6_2.jpg: 8
# Predicted digit for ./Data/22520083\6\hinh_6_3.jpg: 8
# Predicted digit for ./Data/22520083\7\hinh_7_1.jpg: 8
# Predicted digit for ./Data/22520083\7\hinh_7_2.jpg: 8
# Predicted digit for ./Data/22520083\7\hinh_7_3.jpg: 8
# Predicted digit for ./Data/22520083\8\hinh_8_1.jpg: 8
# Predicted digit for ./Data/22520083\8\hinh_8_2.jpg: 8
# Predicted digit for ./Data/22520083\8\hinh_8_3.jpg: 8
# Predicted digit for ./Data/22520083\9\hinh_9_1.jpg: 8
# Predicted digit for ./Data/22520083\9\hinh_9_2.jpg: 8
# Predicted digit for ./Data/22520083\9\hinh_9_3.jpg: 8
# Predicted digit for ./Data/22520148\0\0_0.png: 8
# Predicted digit for ./Data/22520148\0\0_1.png: 8
# Predicted digit for ./Data/22520148\0\0_3.png: 8
# Predicted digit for ./Data/22520148\0\HC.png: 9
# Predicted digit for ./Data/22520148\1\1_0.png: 8
# Predicted digit for ./Data/22520148\1\1_1.png: 8
# Predicted digit for ./Data/22520148\1\1_2.png: 6
# Predicted digit for ./Data/22520148\2\2_0.png: 8
# Predicted digit for ./Data/22520148\2\2_1.png: 2
# Predicted digit for ./Data/22520148\2\2_2.png: 8
# Predicted digit for ./Data/22520148\3\3_0.png: 8
# Predicted digit for ./Data/22520148\3\3_1.png: 8
# Predicted digit for ./Data/22520148\3\3_2.png: 3
# Predicted digit for ./Data/22520148\4\4_0.png: 8
# Predicted digit for ./Data/22520148\4\4_1.png: 8
# Predicted digit for ./Data/22520148\4\4_2.png: 2
# Predicted digit for ./Data/22520148\5\5_0.png: 5
# Predicted digit for ./Data/22520148\5\5_1.png: 5
# Predicted digit for ./Data/22520148\5\5_2.png: 8
# Predicted digit for ./Data/22520148\6\6_0.png: 8
# Predicted digit for ./Data/22520148\6\6_1.png: 3
# Predicted digit for ./Data/22520148\6\6_2.png: 3
# Predicted digit for ./Data/22520148\7\7_0.png: 8
# Predicted digit for ./Data/22520148\7\7_1.png: 8
# Predicted digit for ./Data/22520148\7\7_2.png: 7
# Predicted digit for ./Data/22520148\8\8_0.png: 8
# Predicted digit for ./Data/22520148\8\8_1.png: 8
# Predicted digit for ./Data/22520148\8\8_2.png: 8
# Predicted digit for ./Data/22520148\9\9_0.png: 8
# Predicted digit for ./Data/22520148\9\9_1.png: 3
# Predicted digit for ./Data/22520148\9\9_2.png: 8

# %%
# entry point, run the example
#run_example()
